# %% [markdown]
# # Assignment Solution – Player Re-Identification

# %%
import cv2
import numpy as np
import torch
import torchvision.models as models
import torchvision.transforms as T
from ultralytics import YOLO

# Set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Load pre-trained ResNet18 and remove the final layer for embeddings
resnet = models.resnet18(weights='IMAGENET1K_V1')
resnet.fc = torch.nn.Identity()
resnet = resnet.to(device).eval()

# Define preprocessing pipeline
transform = T.Compose([
    T.ToPILImage(),
    T.Resize((224, 224)),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225])
])

# Extract feature vector from a cropped image using ResNet18
def extract_embedding(crop):
    try:
        img_tensor = transform(crop).unsqueeze(0).to(device)
        with torch.no_grad():
            features = resnet(img_tensor)
        return features.squeeze().cpu().numpy()
    except:
        return None  # If transform or embedding fails

# Check spatial proximity between two bounding boxes
def is_spatially_near(box1, box2, max_dist=100):
    cx1 = (box1[0] + box1[2]) / 2
    cy1 = (box1[1] + box1[3]) / 2
    cx2 = (box2[0] + box2[2]) / 2
    cy2 = (box2[1] + box2[3]) / 2
    return np.hypot(cx1 - cx2, cy1 - cy2) < max_dist

# Try to match player based on both appearance and spatial closeness
def match_player_id(embedding, box, player_db, threshold=0.75):
    best_id = None
    best_score = -1
    for pid, (saved_emb, saved_box) in player_db.items():
        if not is_spatially_near(box, saved_box):
            continue
        sim = np.dot(embedding, saved_emb) / (np.linalg.norm(embedding) * np.linalg.norm(saved_emb))
        if sim > threshold and sim > best_score:
            best_score = sim
            best_id = pid
    return best_id

# Load YOLOv8/YOLOv11 model
model = YOLO("best.pt")  # Make sure to use correct weights

# Open input video and prepare output
cap = cv2.VideoCapture("15sec_input_720p.mp4")
width = int(cap.get(3))
height = int(cap.get(4))
fps = int(cap.get(cv2.CAP_PROP_FPS))
out = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*'XVID'), fps, (width, height))

# Track player ID assignments
player_db = {}   # id -> (embedding, last known box)
next_id = 0

# Frame processing loop
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    detections = results[0].boxes

    for det in detections:
        cls_id = int(det.cls.item())
        class_name = results[0].names[cls_id]

        # Only process 'player' class
        if class_name.lower() != "player":
            continue

        x1, y1, x2, y2 = map(int, det.xyxy[0].tolist())
        if x2 <= x1 or y2 <= y1:
            continue

        crop = frame[y1:y2, x1:x2]
        if crop.size == 0:
            continue

        embedding = extract_embedding(crop)
        if embedding is None:
            continue

        # Match or assign a new ID
        matched_id = match_player_id(embedding, (x1, y1, x2, y2), player_db)
        if matched_id is None:
            matched_id = next_id
            next_id += 1

        player_db[matched_id] = (embedding, (x1, y1, x2, y2))

        # Annotate frame with ID
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f"ID: {matched_id}", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)

    out.write(frame)
    cv2.imshow("Tracking", frame)
    if cv2.waitKey(1) == 27:  # ESC to stop
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 ball, 16 players, 2 referees, 773.7ms
# Speed: 3.9ms preprocess, 773.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 805.4ms
# Speed: 2.8ms preprocess, 805.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 783.5ms
# Speed: 3.5ms preprocess, 783.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 738.3ms
# Speed: 2.0ms preprocess, 738.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 749.2ms
# Speed: 2.2ms preprocess, 749.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 759.7ms
# Speed: 1.8ms preprocess, 759.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 770.8ms
# Speed: 2.3ms preprocess, 770.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 805.4ms
# Speed: 2.9ms preprocess, 805.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 827.8ms
# Speed: 2.2ms preprocess, 827.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 810.7ms
# Speed: 2.4ms preprocess, 810.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 939.7ms
# Speed: 3.5ms preprocess, 939.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 873.1ms
# Speed: 2.7ms preprocess, 873.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 869.9ms
# Speed: 2.2ms preprocess, 869.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 890.1ms
# Speed: 2.2ms preprocess, 890.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 879.9ms
# Speed: 2.0ms preprocess, 879.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 905.1ms
# Speed: 2.2ms preprocess, 905.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 886.8ms
# Speed: 2.3ms preprocess, 886.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 966.3ms
# Speed: 2.7ms preprocess, 966.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1087.1ms
# Speed: 7.0ms preprocess, 1087.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 975.4ms
# Speed: 3.1ms preprocess, 975.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 980.2ms
# Speed: 2.8ms preprocess, 980.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 951.3ms
# Speed: 3.9ms preprocess, 951.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 927.2ms
# Speed: 3.3ms preprocess, 927.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 957.0ms
# Speed: 2.2ms preprocess, 957.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 941.5ms
# Speed: 1.9ms preprocess, 941.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 944.1ms
# Speed: 2.5ms preprocess, 944.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1014.0ms
# Speed: 3.4ms preprocess, 1014.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 1037.2ms
# Speed: 2.5ms preprocess, 1037.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 2 referees, 1055.7ms
# Speed: 2.7ms preprocess, 1055.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 16 players, 2 referees, 962.1ms
# Speed: 2.2ms preprocess, 962.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 15 players, 2 referees, 992.7ms
# Speed: 3.5ms preprocess, 992.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 983.7ms
# Speed: 2.1ms preprocess, 983.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 923.0ms
# Speed: 2.4ms preprocess, 923.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 909.1ms
# Speed: 2.4ms preprocess, 909.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 909.2ms
# Speed: 2.2ms preprocess, 909.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3 referees, 1001.1ms
# Speed: 2.3ms preprocess, 1001.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 901.5ms
# Speed: 3.0ms preprocess, 901.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 885.7ms
# Speed: 2.5ms preprocess, 885.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 917.9ms
# Speed: 3.0ms preprocess, 917.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 902.1ms
# Speed: 2.1ms preprocess, 902.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 3 referees, 911.2ms
# Speed: 3.9ms preprocess, 911.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 896.2ms
# Speed: 2.2ms preprocess, 896.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 913.8ms
# Speed: 2.2ms preprocess, 913.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 904.3ms
# Speed: 2.4ms preprocess, 904.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 932.2ms
# Speed: 2.6ms preprocess, 932.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 901.5ms
# Speed: 2.7ms preprocess, 901.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 925.3ms
# Speed: 2.5ms preprocess, 925.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 940.9ms
# Speed: 2.5ms preprocess, 940.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 907.9ms
# Speed: 2.5ms preprocess, 907.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 1000.7ms
# Speed: 2.1ms preprocess, 1000.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 898.7ms
# Speed: 2.2ms preprocess, 898.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 3 referees, 925.1ms
# Speed: 2.6ms preprocess, 925.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 969.2ms
# Speed: 2.1ms preprocess, 969.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 915.6ms
# Speed: 2.2ms preprocess, 915.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 1020.1ms
# Speed: 2.2ms preprocess, 1020.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 985.1ms
# Speed: 2.7ms preprocess, 985.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 926.6ms
# Speed: 3.6ms preprocess, 926.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 1027.4ms
# Speed: 2.3ms preprocess, 1027.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 939.8ms
# Speed: 2.1ms preprocess, 939.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 954.0ms
# Speed: 2.1ms preprocess, 954.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 944.1ms
# Speed: 3.2ms preprocess, 944.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1013.5ms
# Speed: 2.7ms preprocess, 1013.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 927.2ms
# Speed: 2.1ms preprocess, 927.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 941.4ms
# Speed: 2.4ms preprocess, 941.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 924.2ms
# Speed: 2.8ms preprocess, 924.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 4 referees, 985.8ms
# Speed: 2.4ms preprocess, 985.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 922.1ms
# Speed: 2.8ms preprocess, 922.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 4 referees, 973.5ms
# Speed: 3.3ms preprocess, 973.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1067.8ms
# Speed: 2.9ms preprocess, 1067.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 981.7ms
# Speed: 2.6ms preprocess, 981.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 983.3ms
# Speed: 2.3ms preprocess, 983.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 983.2ms
# Speed: 2.4ms preprocess, 983.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 993.8ms
# Speed: 2.4ms preprocess, 993.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1051.3ms
# Speed: 3.5ms preprocess, 1051.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1052.6ms
# Speed: 2.4ms preprocess, 1052.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1025.8ms
# Speed: 4.8ms preprocess, 1025.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 988.0ms
# Speed: 3.1ms preprocess, 988.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 921.6ms
# Speed: 2.2ms preprocess, 921.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 937.3ms
# Speed: 2.3ms preprocess, 937.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 902.8ms
# Speed: 4.2ms preprocess, 902.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 931.6ms
# Speed: 2.2ms preprocess, 931.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 891.6ms
# Speed: 2.6ms preprocess, 891.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 925.4ms
# Speed: 2.2ms preprocess, 925.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 905.2ms
# Speed: 2.0ms preprocess, 905.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 900.8ms
# Speed: 2.6ms preprocess, 900.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 922.9ms
# Speed: 3.1ms preprocess, 922.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 914.4ms
# Speed: 2.1ms preprocess, 914.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 948.3ms
# Speed: 2.5ms preprocess, 948.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 898.1ms
# Speed: 2.3ms preprocess, 898.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 944.4ms
# Speed: 2.4ms preprocess, 944.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 937.4ms
# Speed: 2.8ms preprocess, 937.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 914.3ms
# Speed: 2.4ms preprocess, 914.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 930.2ms
# Speed: 2.3ms preprocess, 930.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 939.4ms
# Speed: 2.5ms preprocess, 939.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 957.1ms
# Speed: 2.3ms preprocess, 957.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 950.0ms
# Speed: 2.3ms preprocess, 950.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 918.0ms
# Speed: 2.3ms preprocess, 918.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 933.7ms
# Speed: 2.9ms preprocess, 933.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 900.5ms
# Speed: 2.6ms preprocess, 900.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 899.9ms
# Speed: 4.5ms preprocess, 899.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 899.2ms
# Speed: 2.4ms preprocess, 899.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 935.0ms
# Speed: 2.7ms preprocess, 935.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 907.6ms
# Speed: 2.6ms preprocess, 907.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 904.2ms
# Speed: 2.5ms preprocess, 904.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 942.7ms
# Speed: 3.5ms preprocess, 942.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 952.6ms
# Speed: 2.9ms preprocess, 952.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 940.4ms
# Speed: 2.6ms preprocess, 940.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 949.4ms
# Speed: 2.6ms preprocess, 949.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 915.1ms
# Speed: 2.3ms preprocess, 915.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1021.7ms
# Speed: 2.1ms preprocess, 1021.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 17 players, 940.6ms
# Speed: 3.6ms preprocess, 940.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 928.9ms
# Speed: 2.3ms preprocess, 928.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 19 players, 1 referee, 923.7ms
# Speed: 3.0ms preprocess, 923.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 928.4ms
# Speed: 2.6ms preprocess, 928.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 912.2ms
# Speed: 2.3ms preprocess, 912.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 935.0ms
# Speed: 2.3ms preprocess, 935.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 922.3ms
# Speed: 2.3ms preprocess, 922.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 912.6ms
# Speed: 2.4ms preprocess, 912.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 907.9ms
# Speed: 3.8ms preprocess, 907.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 919.4ms
# Speed: 2.3ms preprocess, 919.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 944.1ms
# Speed: 2.6ms preprocess, 944.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 978.1ms
# Speed: 3.8ms preprocess, 978.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 922.4ms
# Speed: 2.4ms preprocess, 922.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 914.6ms
# Speed: 2.4ms preprocess, 914.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 929.6ms
# Speed: 2.2ms preprocess, 929.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 916.7ms
# Speed: 2.8ms preprocess, 916.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 931.7ms
# Speed: 2.8ms preprocess, 931.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 925.2ms
# Speed: 2.3ms preprocess, 925.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 932.2ms
# Speed: 2.4ms preprocess, 932.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 932.7ms
# Speed: 2.7ms preprocess, 932.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1001.3ms
# Speed: 2.5ms preprocess, 1001.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 992.6ms
# Speed: 2.4ms preprocess, 992.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 18 players, 1 referee, 1101.4ms
# Speed: 2.5ms preprocess, 1101.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 960.9ms
# Speed: 2.5ms preprocess, 960.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 998.5ms
# Speed: 2.3ms preprocess, 998.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 989.0ms
# Speed: 4.8ms preprocess, 989.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 966.7ms
# Speed: 2.2ms preprocess, 966.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1003.0ms
# Speed: 4.5ms preprocess, 1003.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 1 referee, 951.9ms
# Speed: 2.4ms preprocess, 951.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1008.3ms
# Speed: 2.4ms preprocess, 1008.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 950.1ms
# Speed: 2.7ms preprocess, 950.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 973.9ms
# Speed: 2.8ms preprocess, 973.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 947.8ms
# Speed: 2.4ms preprocess, 947.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 949.3ms
# Speed: 2.3ms preprocess, 949.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 949.0ms
# Speed: 2.3ms preprocess, 949.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 991.5ms
# Speed: 2.5ms preprocess, 991.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1110.0ms
# Speed: 3.3ms preprocess, 1110.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1018.4ms
# Speed: 2.9ms preprocess, 1018.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 944.5ms
# Speed: 2.7ms preprocess, 944.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 943.2ms
# Speed: 2.7ms preprocess, 943.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 945.2ms
# Speed: 2.4ms preprocess, 945.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 953.1ms
# Speed: 2.4ms preprocess, 953.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 945.5ms
# Speed: 2.2ms preprocess, 945.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 969.0ms
# Speed: 2.4ms preprocess, 969.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1041.0ms
# Speed: 2.9ms preprocess, 1041.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1135.0ms
# Speed: 3.7ms preprocess, 1135.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 946.3ms
# Speed: 4.7ms preprocess, 946.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 1063.9ms
# Speed: 3.3ms preprocess, 1063.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 997.8ms
# Speed: 2.4ms preprocess, 997.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 956.8ms
# Speed: 2.4ms preprocess, 956.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 949.5ms
# Speed: 2.3ms preprocess, 949.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1026.7ms
# Speed: 2.4ms preprocess, 1026.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1032.8ms
# Speed: 2.8ms preprocess, 1032.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1007.3ms
# Speed: 2.4ms preprocess, 1007.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1124.6ms
# Speed: 3.0ms preprocess, 1124.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 975.5ms
# Speed: 2.7ms preprocess, 975.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1004.0ms
# Speed: 3.1ms preprocess, 1004.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 962.9ms
# Speed: 2.9ms preprocess, 962.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 966.4ms
# Speed: 2.2ms preprocess, 966.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 ball, 13 players, 982.6ms
# Speed: 2.3ms preprocess, 982.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 986.4ms
# Speed: 2.4ms preprocess, 986.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1016.3ms
# Speed: 2.5ms preprocess, 1016.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 963.3ms
# Speed: 3.2ms preprocess, 963.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 943.9ms
# Speed: 2.7ms preprocess, 943.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1004.6ms
# Speed: 3.2ms preprocess, 1004.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1061.3ms
# Speed: 3.8ms preprocess, 1061.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 968.5ms
# Speed: 2.8ms preprocess, 968.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 944.6ms
# Speed: 2.7ms preprocess, 944.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1191.2ms
# Speed: 5.0ms preprocess, 1191.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 11 players, 1 referee, 1105.0ms
# Speed: 3.0ms preprocess, 1105.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1262.3ms
# Speed: 3.7ms preprocess, 1262.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1016.8ms
# Speed: 2.9ms preprocess, 1016.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 1010.3ms
# Speed: 3.2ms preprocess, 1010.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1101.1ms
# Speed: 2.4ms preprocess, 1101.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1072.3ms
# Speed: 2.4ms preprocess, 1072.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1000.9ms
# Speed: 2.9ms preprocess, 1000.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1117.5ms
# Speed: 3.7ms preprocess, 1117.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 995.5ms
# Speed: 2.8ms preprocess, 995.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1225.9ms
# Speed: 2.5ms preprocess, 1225.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1 referee, 1016.6ms
# Speed: 3.6ms preprocess, 1016.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 974.9ms
# Speed: 2.9ms preprocess, 974.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1035.4ms
# Speed: 3.3ms preprocess, 1035.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1230.3ms
# Speed: 4.6ms preprocess, 1230.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 14 players, 1083.7ms
# Speed: 4.4ms preprocess, 1083.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 967.3ms
# Speed: 2.5ms preprocess, 967.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 991.3ms
# Speed: 3.6ms preprocess, 991.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 1034.0ms
# Speed: 3.2ms preprocess, 1034.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1042.0ms
# Speed: 2.3ms preprocess, 1042.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 939.1ms
# Speed: 2.8ms preprocess, 939.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 977.8ms
# Speed: 2.4ms preprocess, 977.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 952.0ms
# Speed: 2.6ms preprocess, 952.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 932.8ms
# Speed: 2.4ms preprocess, 932.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 948.3ms
# Speed: 2.6ms preprocess, 948.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 980.7ms
# Speed: 2.6ms preprocess, 980.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 970.1ms
# Speed: 2.4ms preprocess, 970.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 978.4ms
# Speed: 2.3ms preprocess, 978.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 984.7ms
# Speed: 2.3ms preprocess, 984.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1035.6ms
# Speed: 2.5ms preprocess, 1035.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 989.7ms
# Speed: 3.0ms preprocess, 989.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 986.1ms
# Speed: 2.7ms preprocess, 986.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 997.1ms
# Speed: 3.3ms preprocess, 997.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 972.4ms
# Speed: 3.0ms preprocess, 972.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 946.4ms
# Speed: 3.7ms preprocess, 946.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 944.7ms
# Speed: 2.4ms preprocess, 944.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 10 players, 943.9ms
# Speed: 2.5ms preprocess, 943.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 941.8ms
# Speed: 2.3ms preprocess, 941.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 938.9ms
# Speed: 2.4ms preprocess, 938.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 941.4ms
# Speed: 2.5ms preprocess, 941.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 942.4ms
# Speed: 2.4ms preprocess, 942.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 940.3ms
# Speed: 2.3ms preprocess, 940.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 941.8ms
# Speed: 2.3ms preprocess, 941.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 942.9ms
# Speed: 2.6ms preprocess, 942.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1021.6ms
# Speed: 4.0ms preprocess, 1021.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1012.3ms
# Speed: 2.9ms preprocess, 1012.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 965.2ms
# Speed: 2.7ms preprocess, 965.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 990.5ms
# Speed: 2.8ms preprocess, 990.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 9 players, 942.0ms
# Speed: 2.4ms preprocess, 942.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 945.3ms
# Speed: 2.4ms preprocess, 945.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 957.1ms
# Speed: 2.4ms preprocess, 957.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 2 balls, 1 goalkeeper, 11 players, 1026.4ms
# Speed: 2.5ms preprocess, 1026.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1126.9ms
# Speed: 2.8ms preprocess, 1126.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 969.7ms
# Speed: 2.5ms preprocess, 969.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 1054.4ms
# Speed: 2.5ms preprocess, 1054.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 8 players, 1122.9ms
# Speed: 4.3ms preprocess, 1122.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1024.5ms
# Speed: 3.1ms preprocess, 1024.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1078.8ms
# Speed: 2.5ms preprocess, 1078.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 982.3ms
# Speed: 2.7ms preprocess, 982.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 962.2ms
# Speed: 3.1ms preprocess, 962.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 986.7ms
# Speed: 2.3ms preprocess, 986.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 981.8ms
# Speed: 3.6ms preprocess, 981.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 993.1ms
# Speed: 3.1ms preprocess, 993.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 993.5ms
# Speed: 2.4ms preprocess, 993.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 941.3ms
# Speed: 2.4ms preprocess, 941.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 942.9ms
# Speed: 3.0ms preprocess, 942.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 942.5ms
# Speed: 3.0ms preprocess, 942.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 954.6ms
# Speed: 2.4ms preprocess, 954.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1009.8ms
# Speed: 2.4ms preprocess, 1009.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 1021.3ms
# Speed: 2.7ms preprocess, 1021.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 991.4ms
# Speed: 2.2ms preprocess, 991.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 968.0ms
# Speed: 2.3ms preprocess, 968.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 998.4ms
# Speed: 2.6ms preprocess, 998.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 970.6ms
# Speed: 3.7ms preprocess, 970.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1104.2ms
# Speed: 2.6ms preprocess, 1104.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 970.6ms
# Speed: 2.1ms preprocess, 970.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 968.3ms
# Speed: 2.4ms preprocess, 968.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 977.2ms
# Speed: 4.0ms preprocess, 977.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 981.1ms
# Speed: 2.6ms preprocess, 981.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 947.3ms
# Speed: 2.3ms preprocess, 947.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 1002.5ms
# Speed: 2.4ms preprocess, 1002.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 969.1ms
# Speed: 2.8ms preprocess, 969.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 976.1ms
# Speed: 2.9ms preprocess, 976.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 961.4ms
# Speed: 2.7ms preprocess, 961.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 958.5ms
# Speed: 2.3ms preprocess, 958.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 970.2ms
# Speed: 2.5ms preprocess, 970.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 970.1ms
# Speed: 2.8ms preprocess, 970.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 943.7ms
# Speed: 2.3ms preprocess, 943.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 965.8ms
# Speed: 2.3ms preprocess, 965.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 988.9ms
# Speed: 2.5ms preprocess, 988.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 976.3ms
# Speed: 2.5ms preprocess, 976.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 951.7ms
# Speed: 2.3ms preprocess, 951.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 958.0ms
# Speed: 2.7ms preprocess, 958.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 969.0ms
# Speed: 2.8ms preprocess, 969.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 960.6ms
# Speed: 3.0ms preprocess, 960.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 993.0ms
# Speed: 2.3ms preprocess, 993.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 957.3ms
# Speed: 2.7ms preprocess, 957.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 988.6ms
# Speed: 2.5ms preprocess, 988.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 979.4ms
# Speed: 4.9ms preprocess, 979.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 955.8ms
# Speed: 2.8ms preprocess, 955.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 941.7ms
# Speed: 2.6ms preprocess, 941.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1073.9ms
# Speed: 2.6ms preprocess, 1073.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 960.7ms
# Speed: 2.4ms preprocess, 960.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1002.5ms
# Speed: 2.9ms preprocess, 1002.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 961.0ms
# Speed: 2.4ms preprocess, 961.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 968.8ms
# Speed: 2.4ms preprocess, 968.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1074.7ms
# Speed: 2.6ms preprocess, 1074.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1022.0ms
# Speed: 2.5ms preprocess, 1022.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 962.4ms
# Speed: 2.2ms preprocess, 962.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 goalkeeper, 15 players, 945.2ms
# Speed: 2.6ms preprocess, 945.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 945.9ms
# Speed: 2.6ms preprocess, 945.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 996.4ms
# Speed: 2.8ms preprocess, 996.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 974.6ms
# Speed: 2.5ms preprocess, 974.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 966.0ms
# Speed: 2.6ms preprocess, 966.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 973.5ms
# Speed: 2.4ms preprocess, 973.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 939.8ms
# Speed: 2.2ms preprocess, 939.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 998.9ms
# Speed: 2.6ms preprocess, 998.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 939.7ms
# Speed: 2.4ms preprocess, 939.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 940.7ms
# Speed: 4.0ms preprocess, 940.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 976.0ms
# Speed: 2.5ms preprocess, 976.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 976.1ms
# Speed: 3.0ms preprocess, 976.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 972.4ms
# Speed: 2.5ms preprocess, 972.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 963.9ms
# Speed: 2.7ms preprocess, 963.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 939.3ms
# Speed: 2.4ms preprocess, 939.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 1009.5ms
# Speed: 2.6ms preprocess, 1009.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 977.7ms
# Speed: 2.3ms preprocess, 977.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 998.2ms
# Speed: 2.5ms preprocess, 998.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1033.9ms
# Speed: 2.5ms preprocess, 1033.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 985.9ms
# Speed: 2.8ms preprocess, 985.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 1075.2ms
# Speed: 3.1ms preprocess, 1075.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 966.9ms
# Speed: 2.3ms preprocess, 966.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 946.5ms
# Speed: 2.4ms preprocess, 946.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 958.8ms
# Speed: 2.5ms preprocess, 958.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 1041.9ms
# Speed: 2.7ms preprocess, 1041.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 1144.6ms
# Speed: 3.4ms preprocess, 1144.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 973.0ms
# Speed: 2.7ms preprocess, 973.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 930.5ms
# Speed: 3.8ms preprocess, 930.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 930.9ms
# Speed: 2.9ms preprocess, 930.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 952.2ms
# Speed: 3.0ms preprocess, 952.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 992.4ms
# Speed: 2.3ms preprocess, 992.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 16 players, 945.3ms
# Speed: 2.5ms preprocess, 945.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 966.4ms
# Speed: 2.3ms preprocess, 966.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 984.8ms
# Speed: 2.5ms preprocess, 984.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 969.5ms
# Speed: 2.7ms preprocess, 969.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 965.4ms
# Speed: 2.5ms preprocess, 965.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 962.1ms
# Speed: 2.9ms preprocess, 962.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 941.6ms
# Speed: 2.4ms preprocess, 941.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 972.6ms
# Speed: 2.9ms preprocess, 972.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 962.1ms
# Speed: 2.5ms preprocess, 962.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 946.0ms
# Speed: 2.4ms preprocess, 946.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 976.2ms
# Speed: 3.9ms preprocess, 976.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1019.5ms
# Speed: 2.6ms preprocess, 1019.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 959.4ms
# Speed: 2.6ms preprocess, 959.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 966.2ms
# Speed: 2.8ms preprocess, 966.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1076.7ms
# Speed: 2.5ms preprocess, 1076.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1204.6ms
# Speed: 3.0ms preprocess, 1204.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 973.2ms
# Speed: 4.4ms preprocess, 973.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 958.7ms
# Speed: 2.6ms preprocess, 958.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 958.4ms
# Speed: 2.4ms preprocess, 958.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 953.3ms
# Speed: 2.3ms preprocess, 953.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 971.4ms
# Speed: 2.8ms preprocess, 971.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 947.4ms
# Speed: 2.7ms preprocess, 947.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 967.0ms
# Speed: 2.6ms preprocess, 967.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 948.8ms
# Speed: 3.0ms preprocess, 948.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 955.3ms
# Speed: 2.3ms preprocess, 955.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 980.3ms
# Speed: 2.8ms preprocess, 980.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2210.8ms
# Speed: 14.8ms preprocess, 2210.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1338.2ms
# Speed: 3.1ms preprocess, 1338.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1476.4ms
# Speed: 3.8ms preprocess, 1476.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 13 players, 1327.1ms
# Speed: 2.5ms preprocess, 1327.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1165.3ms
# Speed: 2.9ms preprocess, 1165.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1124.1ms
# Speed: 2.6ms preprocess, 1124.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1062.8ms
# Speed: 3.2ms preprocess, 1062.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1013.3ms
# Speed: 3.6ms preprocess, 1013.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1028.6ms
# Speed: 2.6ms preprocess, 1028.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 964.1ms
# Speed: 2.3ms preprocess, 964.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 969.2ms
# Speed: 2.6ms preprocess, 969.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1041.8ms
# Speed: 2.7ms preprocess, 1041.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1018.3ms
# Speed: 2.3ms preprocess, 1018.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1044.5ms
# Speed: 2.5ms preprocess, 1044.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1000.9ms
# Speed: 2.4ms preprocess, 1000.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 969.2ms
# Speed: 3.1ms preprocess, 969.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1018.8ms
# Speed: 2.4ms preprocess, 1018.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1522.2ms
# Speed: 3.8ms preprocess, 1522.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1085.6ms
# Speed: 2.9ms preprocess, 1085.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 998.0ms
# Speed: 2.5ms preprocess, 998.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 967.6ms
# Speed: 2.3ms preprocess, 967.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 983.8ms
# Speed: 2.3ms preprocess, 983.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1132.3ms
# Speed: 2.3ms preprocess, 1132.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 975.4ms
# Speed: 2.4ms preprocess, 975.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 950.3ms
# Speed: 2.3ms preprocess, 950.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1019.7ms
# Speed: 4.6ms preprocess, 1019.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 951.5ms
# Speed: 2.4ms preprocess, 951.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 949.2ms
# Speed: 2.3ms preprocess, 949.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 987.2ms
# Speed: 2.8ms preprocess, 987.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 950.3ms
# Speed: 2.1ms preprocess, 950.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 950.5ms
# Speed: 2.6ms preprocess, 950.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
